# %%
# !pip install kaggle -q #menginstal pustaka Kaggle di lingkungan Google Colab.

from google.colab import files #mengimpor modul files dari pustaka google.colab

# %%
# Upload the Kaggle API key (kaggle.json)
# kaggle.json adalah file konfigurasi yang berisi informasi otentikasi yang diperlukan untuk mengakses API Kaggle

uploaded = files.upload()
# Out:
#      <input type="file" id="files-f4d229f7-a4d4-469b-9eee-b07682bb714e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4d229f7-a4d4-469b-9eee-b07682bb714e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Set up Kaggle API credentials

# !mkdir -p ~/.kaggle #membuat direktori ~/.kaggle di dalam sistem file Colab.
# !cp kaggle.json ~/.kaggle/ #menyalin file kaggle.json ke dalam direktori ~/.kaggle/ kemudian menyediakan kredensial Kaggle.
# !chmod 600 ~/.kaggle/kaggle.json #menyatakan bahwa hanya pemilik file yang memiliki izin untuk membaca dan menulis file tersebut.

# %%
# Download dataset directly to the '/content/' directory

# !kaggle datasets download -d raghavrpotdar/fresh-and-stale-images-of-fruits-and-vegetables
# Out:
# fresh-and-stale-images-of-fruits-and-vegetables.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Create necessary directories
# -p untuk menentukan path

# !mkdir -p 'dataset/train'
# !mkdir -p 'dataset/dev'
# !mkdir -p 'dataset/test'

# %%
# Buat temporary folder untuk hasil unzip dataset

# !mkdir dirty_data

# %%
# Unzip the dataset directly to the desired location

# !unzip -q fresh-and-stale-images-of-fruits-and-vegetables.zip  "fresh_apple/*" -d "dirty_data/"
# !unzip -q fresh-and-stale-images-of-fruits-and-vegetables.zip  "fresh_orange/*" -d "dirty_data/"
# !unzip -q fresh-and-stale-images-of-fruits-and-vegetables.zip  "fresh_banana/*" -d "dirty_data/"
# !unzip -q fresh-and-stale-images-of-fruits-and-vegetables.zip  "stale_apple/*" -d "dirty_data/"
# !unzip -q fresh-and-stale-images-of-fruits-and-vegetables.zip  "stale_orange/*" -d "dirty_data/"
# !unzip -q fresh-and-stale-images-of-fruits-and-vegetables.zip  "stale_banana/*" -d "dirty_data/"

# %% [markdown]
# ## cek jumlah file

# %%
import os

def hitung_jumlah_file(folder_path):
    # Mengecek apakah folder_path adalah direktori
    if os.path.isdir(folder_path):
        # Menggunakan list comprehension untuk menghitung jumlah file dalam folder
        jumlah_file = len([nama_file for nama_file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, nama_file))])
        return jumlah_file
    else:
        return "Path yang diberikan bukan direktori."

folder_path1 = '/content/dirty_data/fresh_apple'
folder_path2 = '/content/dirty_data/fresh_banana'
folder_path3 = '/content/dirty_data/fresh_orange'
folder_path4 = '/content/dirty_data/stale_apple'
folder_path5 = '/content/dirty_data/stale_banana'
folder_path6 = '/content/dirty_data/stale_orange'

jumlah_file1 = hitung_jumlah_file(folder_path1)
jumlah_file2 = hitung_jumlah_file(folder_path2)
jumlah_file3 = hitung_jumlah_file(folder_path3)
jumlah_file4 = hitung_jumlah_file(folder_path4)
jumlah_file5 = hitung_jumlah_file(folder_path5)
jumlah_file6 = hitung_jumlah_file(folder_path6)

print(f"Jumlah file dalam folder fresh_apple: {jumlah_file1}")
print(f"Jumlah file dalam folder fresh_banana: {jumlah_file2}")
print(f"Jumlah file dalam folder fresh_orange: {jumlah_file3}")
print(f"Jumlah file dalam folder stale_apple: {jumlah_file4}")
print(f"Jumlah file dalam folder stale_banana: {jumlah_file5}")
print(f"Jumlah file dalam folder stale_orange: {jumlah_file6}")
# Out:
# Jumlah file dalam folder fresh_apple: 1693
# Jumlah file dalam folder fresh_banana: 1581
# Jumlah file dalam folder fresh_orange: 1466
# Jumlah file dalam folder stale_apple: 2342
# Jumlah file dalam folder stale_banana: 1467
# Jumlah file dalam folder stale_orange: 1595

# %%
# menggunakan loop for di dalam shell untuk melakukan perubahan nama file

# !for file in dirty_data/fresh_apple/*; do mv "$file" "${file// /_}" >/dev/null 2>&1; done
# !for file in dirty_data/fresh_banana/*; do mv "$file" "${file// /_}" >/dev/null 2>&1; done
# !for file in dirty_data/fresh_orange/*; do mv "$file" "${file// /_}" >/dev/null 2>&1; done
# !for file in dirty_data/stale_apple/*; do mv "$file" "${file// /_}" >/dev/null 2>&1; done
# !for file in dirty_data/stale_banana/*; do mv "$file" "${file// /_}" >/dev/null 2>&1; done
# !for file in dirty_data/stale_orange/*; do mv "$file" "${file// /_}" >/dev/null 2>&1; done

# %%
# !ls -d dirty_data/fresh_apple/* | tail -n +1001 | xargs rm
# !ls -d dirty_data/fresh_banana/* | tail -n +1001 | xargs rm
# !ls -d dirty_data/fresh_orange/* | tail -n +1001 | xargs rm
# !ls -d dirty_data/stale_apple/* | tail -n +1001 | xargs rm
# !ls -d dirty_data/stale_banana/* | tail -n +1001 | xargs rm
# !ls -d dirty_data/stale_orange/* | tail -n +1001 | xargs rm

# %% [markdown]
# ## cek jumlah file setelah dibersihkan

# %%
jumlah_file1 = hitung_jumlah_file(folder_path1)
jumlah_file2 = hitung_jumlah_file(folder_path2)
jumlah_file3 = hitung_jumlah_file(folder_path3)
jumlah_file4 = hitung_jumlah_file(folder_path4)
jumlah_file5 = hitung_jumlah_file(folder_path5)
jumlah_file6 = hitung_jumlah_file(folder_path6)

print(f"Jumlah file dalam folder fresh_apple: {jumlah_file1}")
print(f"Jumlah file dalam folder fresh_banana: {jumlah_file2}")
print(f"Jumlah file dalam folder fresh_orange: {jumlah_file3}")
print(f"Jumlah file dalam folder stale_apple: {jumlah_file4}")
print(f"Jumlah file dalam folder stale_banana: {jumlah_file5}")
print(f"Jumlah file dalam folder stale_orange: {jumlah_file6}")
# Out:
# Jumlah file dalam folder fresh_apple: 1000
# Jumlah file dalam folder fresh_banana: 1000
# Jumlah file dalam folder fresh_orange: 1000
# Jumlah file dalam folder stale_apple: 1000
# Jumlah file dalam folder stale_banana: 1000
# Jumlah file dalam folder stale_orange: 1000

# %%
# !pip install split-folders -q

# %%
import splitfolders

splitfolders.fixed("dirty_data", output="temp_folder", seed=42, fixed=(150, 150))
# Out:
# Copying files: 6000 files [00:03, 1665.07 files/s]

# %%
# !mv temp_folder/train/* dataset/train/
# !mv temp_folder/val/* dataset/dev/
# !mv temp_folder/test/* dataset/test/

# %%
# !rm -rf temp_folder
# !rm -rf dirty_data

# %%
# Cell 6
# Check the content of the directories
# !ls /content/dataset/train
# !ls /content/dataset/dev
# !ls /content/dataset/test
# Out:
# fresh_apple  fresh_banana  fresh_orange  stale_apple  stale_banana  stale_orange
# fresh_apple  fresh_banana  fresh_orange  stale_apple  stale_banana  stale_orange
# fresh_apple  fresh_banana  fresh_orange  stale_apple  stale_banana  stale_orange

# %% [markdown]
# ## ubah ukuran gambar jadi 224 X 224 Pixels

# %% [markdown]
# ### fungsi untuk menampilkan gambar secara cak

# %%
# !pip install python-resize-image -q

# %%
import random
from glob import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image
from PIL import Image
from resizeimage import resizeimage

def show_random_images_from(glob_path, seed):
    if seed:
        random.seed(seed)
    r = random.sample(glob(glob_path), 8)
    plt.figure(figsize=(10,6))
    for i, k in enumerate(r):
        plt.subplot(241 + i)
        plt.imshow(Image.open(k))
        plt.axis('off')

# %% [markdown]
# ### sebelum ukuran diubah

# %%
show_random_images_from("dataset/*/*/*", seed=380)

# %% [markdown]
# ### melakukan perubahan ukuran gambar

# %%
for i, img in enumerate(glob("dataset/*/*/*")):
    try:
      image = Image.open(img)
      cover = resizeimage.resize_cover(image, [224, 224])
      cover.save(img)
    except:
      print(img, " ----- error converting, skipped.")
# Out:
# dataset/train/fresh_apple/rotated_by_15_Screen_Shot_2018-06-08_at_5.29.24_PM.png  ----- error converting, skipped.
# dataset/train/fresh_apple/rotated_by_45_Screen_Shot_2018-06-08_at_5.29.18_PM.png  ----- error converting, skipped.
# dataset/train/fresh_apple/rotated_by_75_Screen_Shot_2018-06-08_at_5.10.29_PM.png  ----- error converting, skipped.
# dataset/train/fresh_apple/rotated_by_60_Screen_Shot_2018-06-08_at_5.09.40_PM.png  ----- error converting, skipped.
# dataset/train/fresh_apple/rotated_by_60_Screen_Shot_2018-06-08_at_5.21.06_PM.png  ----- error converting, skipped.
# dataset/train/fresh_apple/rotated_by_45_Screen_Shot_2018-06-08_at_5.22.15_PM.png  ----- error converting, skipped.
# dataset/train/fresh_apple/rotated_by_60_Screen_Shot_2018-06-08_at_5.28.48_PM.png  ----- error converting, skipped.
# dataset/train/fresh_apple/rotated_by_15_Screen_Shot_2018-06-08_at_5.21.51_PM.png  ----- error converting, skipped.
# ...

# %% [markdown]
# ### Simpan dataset ke gdrive

# %%
# Zip dataset folder

# !zip -r -q dataset_buah.zip "/content/dataset/"

# %%
from google.colab import drive

drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Copy dataset bersih ke gdrive

# !cp -r "dataset_buah.zip" "drive/MyDrive/Dataset Capstone/"

# %%
# Cek dataset yang sudah tersimpan

# !ls "drive/MyDrive/Dataset Capstone/"
# Out:
# dataset_buah.zip

# %% [markdown]
# # Bikin Model

# %%
# !pip install gdown -q

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import pathlib
import numpy as np
import matplotlib.pylab as plt

# %%
print(tf. __version__)
# Out:
# 2.14.0

# %%
# # download dataset

# !gdown 'https://drive.google.com/uc?id=1-3EN3nP743RLkyv18BeXDSh-32KTd2VO' -O dataset_buah.zip
# !unzip -q dataset_buah.zip
# !mv /content/content/dataset /content
# !rm -rf /content/content
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-3EN3nP743RLkyv18BeXDSh-32KTd2VO
# To: /content/dataset_buah.zip
# 100% 338M/338M [00:01<00:00, 223MB/s]

# %%
dataset_dir = "/content/dataset"
train_dir = "/content/dataset/train"
valid_dir = "/content/dataset/dev"
test_dir = "/content/dataset/test"

# %% [markdown]
# ## Handle Pre-Trained Model (MobileNetV2)

# %%
handle_base, pixels, FV_SIZE = ("mobilenet_v2", 224, 1280)
MODULE_HANDLE ="https://tfhub.dev/google/tf2-preview/{}/feature_vector/4".format(handle_base)
IMAGE_SIZE = (pixels, pixels)

print("Menggunakan {} dengan input size {} dan output dimension {}".format(MODULE_HANDLE, IMAGE_SIZE, FV_SIZE))
# Out:
# Menggunakan https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4 dengan input size (224, 224) dan output dimension 1280

# %% [markdown]
# ## Data augmentation

# %%
BATCH_SIZE = 64

# %%
# Datagen
train_datagen =  tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen =  ImageDataGenerator(rescale=1./255)

# Flow training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    shuffle=True,
    class_mode='categorical'
)

# Flow validation data generator
validation_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode='categorical'
)

# Flow test data generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode='categorical'
)
# Out:
# Found 4200 images belonging to 6 classes.
# Found 900 images belonging to 6 classes.
# Found 900 images belonging to 6 classes.

# %% [markdown]
# ## Membuat file label.txt yang berisi nama-nama kelas yang dapat di klasifikasi

# %%
class_names = list(train_generator.class_indices.keys())

with open('label.txt', 'w') as f:
    f.write('\n'.join(class_names))

# %% [markdown]
# ## Set Up Feature Extractor

# %%
feature_extractor = hub.KerasLayer(
    MODULE_HANDLE,
    input_shape=IMAGE_SIZE + (3,),
    output_shape=[FV_SIZE],
    trainable=False
)

# %% [markdown]
# ## buat model dengan transfer learning menggunakan mobilenetv2

# %%
print("Buat Model menggunakan", MODULE_HANDLE)

model = tf.keras.Sequential([
    feature_extractor,
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(len(class_names), activation='softmax')
])

model.summary()
# Out:
# Buat Model menggunakan https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 64)                81984
#
#  dense_1 (Dense)             (None, 6)                 390
#
# ...
# Total params: 2340358 (8.93 MB)
# Trainable params: 82374 (321.77 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from keras import callbacks

early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    mode="min",
    patience=3,
    restore_best_weights=True
)

# %%
EPOCHS = 10

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    verbose=1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 66/66 [==============================] - 77s 965ms/step - loss: 0.2550 - accuracy: 0.9179 - val_loss: 0.0933 - val_accuracy: 0.9711
# Epoch 2/10
# 66/66 [==============================] - 61s 922ms/step - loss: 0.0513 - accuracy: 0.9879 - val_loss: 0.0656 - val_accuracy: 0.9833
# Epoch 3/10
# 66/66 [==============================] - 64s 957ms/step - loss: 0.0327 - accuracy: 0.9910 - val_loss: 0.0495 - val_accuracy: 0.9856
# Epoch 4/10
# 66/66 [==============================] - 63s 968ms/step - loss: 0.0199 - accuracy: 0.9957 - val_loss: 0.0428 - val_accuracy: 0.9856
# Epoch 5/10
# 66/66 [==============================] - 62s 936ms/step - loss: 0.0176 - accuracy: 0.9964 - val_loss: 0.0311 - val_accuracy: 0.9889
# Epoch 6/10
# 66/66 [==============================] - 61s 926ms/step - loss: 0.0123 - accuracy: 0.9976 - val_loss: 0.0232 - val_accuracy: 0.9944
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training dan validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training dan validation loss')
plt.legend()
plt.show()

# %%
# Evaluate final score on Validation and Testing data

scores = model.evaluate(validation_generator)
scores = model.evaluate(test_generator)
# Out:
# ...
# 15/15 [==============================] - 3s 202ms/step - loss: 0.0321 - accuracy: 0.9889

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

cm = confusion_matrix(test_generator.classes, y_pred)

print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=class_names))
# Out:
# 15/15 [==============================] - 4s 255ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#  fresh_apple       0.97      0.99      0.98       150
# fresh_banana       1.00      1.00      1.00       150
# fresh_orange       1.00      0.95      0.98       150
#  stale_apple       0.99      0.99      0.99       150
# stale_banana       1.00      1.00      1.00       150
# stale_orange       0.97      1.00      0.98       150
#
#     accuracy                           0.99       900
#    macro avg       0.99      0.99      0.99       900
# weighted avg       0.99      0.99      0.99       900

# %%
model.save('klasifikasi_buah.h5')
model.save('klasifikasi_buah')
# !zip -r 'klasifikasi_buah.zip' 'klasifikasi_buah'
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#   adding: klasifikasi_buah/ (stored 0%)
#   adding: klasifikasi_buah/assets/ (stored 0%)
#   adding: klasifikasi_buah/saved_model.pb (deflated 91%)
#   adding: klasifikasi_buah/fingerprint.pb (stored 0%)
#   adding: klasifikasi_buah/variables/ (stored 0%)
#   adding: klasifikasi_buah/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: klasifikasi_buah/variables/variables.index (deflated 78%)
#   adding: klasifikasi_buah/keras_metadata.pb (deflated 84%)

# %%
# Copy model ke gdrive

# !cp -r "klasifikasi_buah.h5" "drive/MyDrive/Dataset Capstone/"
# Out:
# cp: cannot create regular file 'drive/MyDrive/Dataset Capstone/': No such file or directory

# %% [markdown]
# ## Test Prediksi

# %%
# !gdown 1Uplz-nnFywku3k5Nf6PZ_n9XeV1-P-W_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Uplz-nnFywku3k5Nf6PZ_n9XeV1-P-W_
# To: /content/klasifikasi_buah.h5
# 100% 10.3M/10.3M [00:00<00:00, 93.3MB/s]

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img , img_to_array
import tensorflow_hub as hub
import os


# BASE_DIR = os.path.dirname(os.path.abspath(__file__))
model = load_model(('/content/klasifikasi_buah.h5'), custom_objects={'KerasLayer':hub.KerasLayer})

classes = ['Fresh Apple' ,'Fresh Banana', 'Fresh Orange' , 'Stale Apple' , 'Stale Banana','Stale Orange']
def predict(filename , model):
    img = load_img(filename , target_size = (224, 224))
    img = img_to_array(img)
    img = img.reshape(1 , 224 ,224 ,3)

    img = img.astype('float32')
    img = img/255.0
    result = model.predict(img)

    dict_result = {}
    for i in range(6):
        dict_result[result[0][i]] = classes[i]

    res = result[0]
    res.sort()
    res = res[::-1]
    prob = res[:3]

    prob_result = []
    class_result = []
    for i in range(3):
        prob_result.append((prob[i]*100).round(2))
        class_result.append(dict_result[prob[i]])

    return class_result , prob_result

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from google.colab import files

uploaded = files.upload()
for fn in uploaded.keys():

  # predicting images
  img_path = fn
  # img = load_img(path)

image = mpimg.imread(img_path)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-aca7debf-87df-4773-9748-8bf4afa5a462" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aca7debf-87df-4773-9748-8bf4afa5a462">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# img_path = 'mac and cheese.jpg'

class_result, prob_result = predict(img_path, model)

predictions = {
                      "class":class_result[0],
                      "prob": prob_result[0]
                }
# img = img
predictions = predictions
# predictions = predictions['class1']
# probability = predictions["prob1"]
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
print(f'Classified as : {predictions["class"]}')
print(f'Probability : {predictions["prob"]} %')

# print(predictions)
# print(probability)
# Out:
# Classified as : Fresh Orange
# Probability : 99.98 %
