# %% [markdown]
# # **1. Mounting Google Drive**

# %%
from google.colab import drive
from os.path import join, exists

# mounting dataset dari gdrive
drive.mount('/content/gdrive', force_remount=True)

# folder ini juga digunakan untuk menyimpan model yang sudah dilatih
root_path = 'gdrive/My Drive/Mobile Net Baru/'

# opsional - tampilkan info lokasi dataset
print("Path root:", root_path)
# Out:
# Mounted at /content/gdrive
# Path root: gdrive/My Drive/Mobile Net Baru/

# %%
import os

def hitung_jumlah_file(folder_path):
    # Mengecek apakah folder_path adalah direktori
    if os.path.isdir(folder_path):
        # Menggunakan list comprehension untuk menghitung jumlah file dalam folder
        jumlah_file = len([nama_file for nama_file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, nama_file))])
        return jumlah_file
    else:
        return "Path yang diberikan bukan direktori."

# DATASET SAYUR
# dataset kentang tidak segar
train_path1 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/kentang tidak segar')
valid_path1 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/kentang tidak segar')
test_path1 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/kentang tidak segar')

# dataset kentang segar
train_path2 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/kentang segar')
valid_path2 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/kentang segar')
test_path2 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/kentang segar')

# dataset tomat tidak segar
train_path3 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/tomat tidak segar')
valid_path3 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/tomat tidak segar')
test_path3 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/tomat tidak segar')

# dataset tomat segar
train_path4 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/tomat segar')
valid_path4 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/tomat segar')
test_path4 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/tomat segar')

# dataset wortel tidak segar
train_path5 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/wortel tidak segar')
valid_path5 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/wortel tidak segar')
test_path5 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/wortel tidak segar')

# dataset wortel segar
train_path6 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/wortel segar')
valid_path6 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/wortel segar')
test_path6 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/wortel segar')

# %%
# DATASET BUAH
# dataset apel tidak segar
train_path7 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/apel tidak segar')
valid_path7 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/apel tidak segar')
test_path7 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/apel tidak segar')

# dataset apel segar
train_path8 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/apel segar')
valid_path8 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/apel segar')
test_path8 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/apel segar')

# dataset jeruk tidak segar
train_path9 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/jeruk tidak segar')
valid_path9 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/jeruk tidak segar')
test_path9 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/jeruk tidak segar')

# dataset jeruk segar
train_path10 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/jeruk segar')
valid_path10 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/jeruk segar')
test_path10 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/jeruk segar')

# dataset pisang tidak segar
train_path11 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/pisang tidak segar')
valid_path11 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/pisang tidak segar')
test_path11 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/pisang tidak segar')

# dataset pisang segar
train_path12 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/pisang segar')
valid_path12 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/pisang segar')
test_path12 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/pisang segar')

# %%
# DATASET DAGING SAPI
# dataset daging tidak segar
train_path13 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/daging tidak segar')
valid_path13 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/daging tidak segar')
test_path13 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/daging tidak segar')

# dataset daging segar
train_path14 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/daging segar')
valid_path14 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid/daging segar')
test_path14 = join(root_path, '/content/gdrive/MyDrive/Mobile Net Baru/datasets/test/daging segar')

# %%
# DATASET SAYUR
# dataset kentang tidak segar
jumlah_file1_1 = hitung_jumlah_file(train_path1)
jumlah_file2_1 = hitung_jumlah_file(valid_path1)
jumlah_file3_1 = hitung_jumlah_file(test_path1)

# dataset kentang segar
jumlah_file4_1 = hitung_jumlah_file(train_path2)
jumlah_file5_1 = hitung_jumlah_file(valid_path2)
jumlah_file6_1 = hitung_jumlah_file(test_path2)

# dataset tomat tidak segar
jumlah_file7_1 = hitung_jumlah_file(train_path3)
jumlah_file8_1 = hitung_jumlah_file(valid_path3)
jumlah_file9_1 = hitung_jumlah_file(test_path3)

# dataset tomat segar
jumlah_file10_1 = hitung_jumlah_file(train_path4)
jumlah_file11_1 = hitung_jumlah_file(valid_path4)
jumlah_file12_1 = hitung_jumlah_file(test_path4)

# dataset wortel tidak segar
jumlah_file13_1 = hitung_jumlah_file(train_path5)
jumlah_file14_1 = hitung_jumlah_file(valid_path5)
jumlah_file15_1 = hitung_jumlah_file(test_path5)

# dataset wortel segar
jumlah_file16_1 = hitung_jumlah_file(train_path6)
jumlah_file17_1 = hitung_jumlah_file(valid_path6)
jumlah_file18_1 = hitung_jumlah_file(test_path6)

# %%
# DATASET BUAH
# dataset apel tidak segar
jumlah_file1_2 = hitung_jumlah_file(train_path7)
jumlah_file2_2 = hitung_jumlah_file(valid_path7)
jumlah_file3_2 = hitung_jumlah_file(test_path7)

# dataset apel segar
jumlah_file4_2 = hitung_jumlah_file(train_path8)
jumlah_file5_2 = hitung_jumlah_file(valid_path8)
jumlah_file6_2 = hitung_jumlah_file(test_path8)

# dataset jeruk tidak segar
jumlah_file7_2 = hitung_jumlah_file(train_path9)
jumlah_file8_2 = hitung_jumlah_file(valid_path9)
jumlah_file9_2 = hitung_jumlah_file(test_path9)

# dataset jeruk segar
jumlah_file10_2 = hitung_jumlah_file(train_path10)
jumlah_file11_2 = hitung_jumlah_file(valid_path10)
jumlah_file12_2 = hitung_jumlah_file(test_path10)

# dataset pisang tidak segar
jumlah_file13_2 = hitung_jumlah_file(train_path11)
jumlah_file14_2 = hitung_jumlah_file(valid_path11)
jumlah_file15_2 = hitung_jumlah_file(test_path11)

# dataset pisang segar
jumlah_file16_2 = hitung_jumlah_file(train_path12)
jumlah_file17_2 = hitung_jumlah_file(valid_path12)
jumlah_file18_2 = hitung_jumlah_file(test_path12)

# %%
# DATASET DAGING
# dataset daging tidak segar
jumlah_file1_3 = hitung_jumlah_file(train_path13)
jumlah_file2_3 = hitung_jumlah_file(valid_path13)
jumlah_file3_3 = hitung_jumlah_file(test_path13)

# dataset daging segar
jumlah_file4_3 = hitung_jumlah_file(train_path14)
jumlah_file5_3 = hitung_jumlah_file(valid_path14)
jumlah_file6_3 = hitung_jumlah_file(test_path14)

# %%
# DATA KENTANG

print(f"Jumlah file dalam folder training KENTANG tidak segar: {jumlah_file1_1}")
print(f"Jumlah file dalam folder validasi KENTANG tidak segar: {jumlah_file2_1}")
print(f"Jumlah file dalam folder testing KENTANG tidak segar: {jumlah_file3_1}")

print(f"Jumlah file dalam folder training KENTANG segar: {jumlah_file4_1}")
print(f"Jumlah file dalam folder validasi KENTANG segar: {jumlah_file5_1}")
print(f"Jumlah file dalam folder testing KENTANG segar: {jumlah_file6_1}")
# Out:
# Jumlah file dalam folder training KENTANG tidak segar: 200
# Jumlah file dalam folder validasi KENTANG tidak segar: 100
# Jumlah file dalam folder testing KENTANG tidak segar: 100
# Jumlah file dalam folder training KENTANG segar: 200
# Jumlah file dalam folder validasi KENTANG segar: 100
# Jumlah file dalam folder testing KENTANG segar: 100

# %%
# DATA TOMAT

print(f"Jumlah file dalam folder training TOMAT tidak segar: {jumlah_file7_1}")
print(f"Jumlah file dalam folder validasi TOMAT tidak segar: {jumlah_file8_1}")
print(f"Jumlah file dalam folder testing TOMAT tidak segar: {jumlah_file9_1}")

print(f"Jumlah file dalam folder training TOMAT segar: {jumlah_file10_1}")
print(f"Jumlah file dalam folder validasi TOMAT segar: {jumlah_file11_1}")
print(f"Jumlah file dalam folder testing TOMAT segar: {jumlah_file12_1}")
# Out:
# Jumlah file dalam folder training TOMAT tidak segar: 200
# Jumlah file dalam folder validasi TOMAT tidak segar: 100
# Jumlah file dalam folder testing TOMAT tidak segar: 100
# Jumlah file dalam folder training TOMAT segar: 200
# Jumlah file dalam folder validasi TOMAT segar: 100
# Jumlah file dalam folder testing TOMAT segar: 100

# %%
# DATA WORTEL

print(f"Jumlah file dalam folder training WORTEL tidak segar: {jumlah_file13_1}")
print(f"Jumlah file dalam folder validasi WORTEL tidak segar: {jumlah_file14_1}")
print(f"Jumlah file dalam folder testing WORTEL tidak segar: {jumlah_file15_1}")

print(f"Jumlah file dalam folder training WORTEL segar: {jumlah_file16_1}")
print(f"Jumlah file dalam folder validasi WORTEL segar: {jumlah_file17_1}")
print(f"Jumlah file dalam folder testing WORTEL segar: {jumlah_file18_1}")
# Out:
# Jumlah file dalam folder training WORTEL tidak segar: 200
# Jumlah file dalam folder validasi WORTEL tidak segar: 100
# Jumlah file dalam folder testing WORTEL tidak segar: 100
# Jumlah file dalam folder training WORTEL segar: 200
# Jumlah file dalam folder validasi WORTEL segar: 100
# Jumlah file dalam folder testing WORTEL segar: 100

# %%
# DATA APEL

print(f"Jumlah file dalam folder training APEL tidak segar: {jumlah_file1_2}")
print(f"Jumlah file dalam folder validasi APEL tidak segar: {jumlah_file2_2}")
print(f"Jumlah file dalam folder testing APEL tidak segar: {jumlah_file3_2}")

print(f"Jumlah file dalam folder training APEL segar: {jumlah_file4_2}")
print(f"Jumlah file dalam folder validasi APEL segar: {jumlah_file5_2}")
print(f"Jumlah file dalam folder testing APEL segar: {jumlah_file6_2}")
# Out:
# Jumlah file dalam folder training APEL tidak segar: 200
# Jumlah file dalam folder validasi APEL tidak segar: 100
# Jumlah file dalam folder testing APEL tidak segar: 100
# Jumlah file dalam folder training APEL segar: 200
# Jumlah file dalam folder validasi APEL segar: 100
# Jumlah file dalam folder testing APEL segar: 100

# %%
# DATA JERUK

print(f"Jumlah file dalam folder training JERUK tidak segar: {jumlah_file7_2}")
print(f"Jumlah file dalam folder validasi JERUK tidak segar: {jumlah_file8_2}")
print(f"Jumlah file dalam folder testing JERUK tidak segar: {jumlah_file9_2}")

print(f"Jumlah file dalam folder training JERUK segar: {jumlah_file10_2}")
print(f"Jumlah file dalam folder validasi JERUK segar: {jumlah_file11_2}")
print(f"Jumlah file dalam folder testing JERUK segar: {jumlah_file12_2}")
# Out:
# Jumlah file dalam folder training JERUK tidak segar: 200
# Jumlah file dalam folder validasi JERUK tidak segar: 100
# Jumlah file dalam folder testing JERUK tidak segar: 100
# Jumlah file dalam folder training JERUK segar: 200
# Jumlah file dalam folder validasi JERUK segar: 100
# Jumlah file dalam folder testing JERUK segar: 100

# %%
# DATA PISANG

print(f"Jumlah file dalam folder training PISANG tidak segar: {jumlah_file13_2}")
print(f"Jumlah file dalam folder validasi PISANG tidak segar: {jumlah_file14_2}")
print(f"Jumlah file dalam folder testing PISANG tidak segar: {jumlah_file15_2}")

print(f"Jumlah file dalam folder training PISANG segar: {jumlah_file16_2}")
print(f"Jumlah file dalam folder validasi PISANG segar: {jumlah_file17_2}")
print(f"Jumlah file dalam folder testing PISANG segar: {jumlah_file18_2}")
# Out:
# Jumlah file dalam folder training PISANG tidak segar: 200
# Jumlah file dalam folder validasi PISANG tidak segar: 100
# Jumlah file dalam folder testing PISANG tidak segar: 100
# Jumlah file dalam folder training PISANG segar: 200
# Jumlah file dalam folder validasi PISANG segar: 100
# Jumlah file dalam folder testing PISANG segar: 100

# %%
# DATA DAGING

print(f"Jumlah file dalam folder training DAGING tidak segar: {jumlah_file1_3}")
print(f"Jumlah file dalam folder validasi DAGING tidak segar: {jumlah_file2_3}")
print(f"Jumlah file dalam folder testing DAGING tidak segar: {jumlah_file3_3}")

print(f"Jumlah file dalam folder training DAGING segar: {jumlah_file4_3}")
print(f"Jumlah file dalam folder validasi DAGING segar: {jumlah_file5_3}")
print(f"Jumlah file dalam folder testing DAGING segar: {jumlah_file6_3}")
# Out:
# Jumlah file dalam folder training DAGING tidak segar: 200
# Jumlah file dalam folder validasi DAGING tidak segar: 100
# Jumlah file dalam folder testing DAGING tidak segar: 100
# Jumlah file dalam folder training DAGING segar: 200
# Jumlah file dalam folder validasi DAGING segar: 100
# Jumlah file dalam folder testing DAGING segar: 100

# %% [markdown]
# # **3. Bikin Model**

# %%
# !pip install gdown -q

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import pathlib
import numpy as np
import matplotlib.pylab as plt

# %%
print(tf. __version__)
# Out:
# 2.15.0

# %%
dataset_dir = "/content/gdrive/MyDrive/Mobile Net Baru/datasets/"
train_dir = "/content/gdrive/MyDrive/Mobile Net Baru/datasets/train"
valid_dir = "/content/gdrive/MyDrive/Mobile Net Baru/datasets/valid"
test_dir = "/content/gdrive/MyDrive/Mobile Net Baru/datasets/test"

# %%
# Create directories if they don't exist
for directory in [dataset_dir, train_dir, valid_dir, test_dir]:
    if not os.path.exists(directory):
        os.makedirs(directory)

# %% [markdown]
# ## Handle Pre-Trained Model (MobileNetV2)

# %%
handle_base, pixels, FV_SIZE = ("mobilenet_v2", 224, 1280)
MODULE_HANDLE ="https://tfhub.dev/google/tf2-preview/{}/feature_vector/4".format(handle_base)
IMAGE_SIZE = (pixels, pixels)

print("Menggunakan {} dengan input size {} dan output dimension {}".format(MODULE_HANDLE, IMAGE_SIZE, FV_SIZE))
# Out:
# Menggunakan https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4 dengan input size (224, 224) dan output dimension 1280

# %% [markdown]
# ## Data augmentation

# %%
BATCH_SIZE = 64

train_datagen =  tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen =  ImageDataGenerator(rescale=1./255)

# Flow training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    shuffle=True,
    # classes=classes,
    class_mode='categorical'
)

# Flow validation data generator
validation_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    shuffle=False,
    # classes=classes,
    class_mode='categorical'
)

# Flow test data generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    shuffle=False,
    # classes=classes,
    class_mode='categorical'
)
# Out:
# Found 2800 images belonging to 14 classes.
# Found 1400 images belonging to 14 classes.
# Found 1400 images belonging to 14 classes.

# %% [markdown]
# ## Membuat file label.txt yang berisi nama-nama kelas yang dapat di klasifikasi

# %%
class_names = list(train_generator.class_indices.keys())

with open('label.txt', 'w') as f:
    f.write('\n'.join(class_names))

# %%
# set up feature extractor
feature_extractor = hub.KerasLayer(
    MODULE_HANDLE,
    input_shape=IMAGE_SIZE + (3,),
    output_shape=[FV_SIZE],
    trainable=False
)

# %% [markdown]
# ## buat model dengan transfer learning menggunakan mobilenetv2

# %%
print("Buat Model menggunakan", MODULE_HANDLE)

model = tf.keras.Sequential([
    feature_extractor,
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(len(class_names), activation='softmax')
])

model.summary()
# Out:
# Buat Model menggunakan https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 64)                81984
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 14)                462
#
# ...
# Total params: 2342510 (8.94 MB)
# Trainable params: 84526 (330.18 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from keras import callbacks

early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    mode="min",
    patience=3,
    restore_best_weights=True
)

# %%
EPOCHS = 10

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    verbose=1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 44/44 [==============================] - ETA: 0s - loss: 1.8426 - accuracy: 0.4082
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 44/44 [==============================] - 1021s 24s/step - loss: 1.8426 - accuracy: 0.4082 - val_loss: 0.7440 - val_accuracy: 0.8279
# Epoch 2/10
# 44/44 [==============================] - 121s 3s/step - loss: 0.8218 - accuracy: 0.7486 - val_loss: 0.3479 - val_accuracy: 0.9071
# Epoch 3/10
# 44/44 [==============================] - 121s 3s/step - loss: 0.5373 - accuracy: 0.8275 - val_loss: 0.2961 - val_accuracy: 0.8993
# Epoch 4/10
# 44/44 [==============================] - 120s 3s/step - loss: 0.4030 - accuracy: 0.8746 - val_loss: 0.2169 - val_accuracy: 0.9271
# Epoch 5/10
# 44/44 [==============================] - 120s 3s/step - loss: 0.3317 - accuracy: 0.8929 - val_loss: 0.1419 - val_accuracy: 0.9457
# ...

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training dan validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training dan validation loss')
plt.legend()
plt.show()

# %%
# Evaluate final score on Validation and Testing data

scores = model.evaluate(validation_generator)
scores = model.evaluate(test_generator)
# Out:
# ...
# 22/22 [==============================] - 280s 13s/step - loss: 0.1234 - accuracy: 0.9579

# %%
from sklearn.metrics import classification_report, confusion_matrix

Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

cm = confusion_matrix(test_generator.classes, y_pred)

print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=class_names))
# Out:
# 22/22 [==============================] - 45s 2s/step
# Classification Report
#                      precision    recall  f1-score   support
#
#          apel segar       0.99      0.99      0.99       100
#    apel tidak segar       0.98      1.00      0.99       100
#        daging segar       0.84      0.63      0.72       100
#  daging tidak segar       0.70      0.88      0.78       100
#         jeruk segar       1.00      0.99      0.99       100
#   jeruk tidak segar       1.00      0.99      0.99       100
#       kentang segar       1.00      0.95      0.97       100
# kentang tidak segar       0.95      1.00      0.98       100
#        pisang segar       1.00      1.00      1.00       100
#  pisang tidak segar       1.00      0.99      0.99       100
#         tomat segar       1.00      1.00      1.00       100
#   tomat tidak segar       0.98      1.00      0.99       100
#        wortel segar       1.00      1.00      1.00       100
# ...

# %%
model.save('gdrive/My Drive/Mobile Net Baru/capstone.h5')
model = tf.keras.models.load_model(('gdrive/My Drive/Mobile Net Baru/capstone.h5'), custom_objects={'KerasLayer':hub.KerasLayer})
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
import tensorflow_hub as hub

# Load the saved Keras model with custom objects
model = tf.keras.models.load_model('gdrive/My Drive/Mobile Net Baru/capstone.h5', custom_objects={'KerasLayer': hub.KerasLayer})

# Preprocess the input image
input_image_path = "/content/gdrive/MyDrive/Mobile Net Baru/datasets/train/kentang segar/KentangSegar (1).jpg"  # kentang
# input_image_path = "/content/sunset uad.jpg"  # sunset
input_image = Image.open(input_image_path).resize((224, 224))
input_array = np.expand_dims(np.array(input_image), axis=0)
input_array = input_array.astype(np.float32) / 255.0  # Normalisasi pixel values

# Make predictions
predictions = model.predict(input_array)

# Post-process the output (modify according to your model's output format)
predicted_class = np.argmax(predictions)
confidence = predictions[0][predicted_class]

threshold = 0.5  # Atur ambang batas sesuai kebutuhan

# Check if the highest probability is below the threshold
if confidence < threshold:
    print("Input tidak terdeteksi.")
else:
    print(f"Predicted class: {predicted_class}")
    print(f"Confidence: {confidence}")
# Out:
# 1/1 [==============================] - 0s 349ms/step
# Predicted class: 6
# Confidence: 0.9236488342285156

# %%
# Convert the model to TensorFlow Lite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model
open('gdrive/My Drive/Mobile Net Baru/capstone.tflite', 'wb').write(tflite_model)

# with open("model.tflite", 'wb') as f:
#  f.write(tflite_model)
# Out:
# 9203956

# %% [markdown]
# ## Test Prediksi

# %%
# !gdown
# Out:
# usage: gdown [-h] [-V] [-O OUTPUT] [-q] [--fuzzy] [--id] [--proxy PROXY] [--speed SPEED]
#              [--no-cookies] [--no-check-certificate] [--continue] [--folder] [--remaining-ok]
#              url_or_id
# gdown: error: the following arguments are required: url_or_id

# %%
import os

file_path = 'gdrive/My Drive/Mobile Net/capstone.h5'
if os.path.exists(file_path):
    print(f"File found at {file_path}")
else:
    print(f"File not found at {file_path}")
# Out:
# File found at gdrive/My Drive/Mobile Net/capstone.h5

# %%
from keras.models import load_model
from keras.preprocessing.image import load_img , img_to_array
import tensorflow_hub as hub
import os


# BASE_DIR = os.path.dirname(os.path.abspath(file))
model = load_model(('gdrive/My Drive/Mobile Net/capstone.h5'), custom_objects={'KerasLayer':hub.KerasLayer})

classes = ['Fresh Apple' ,'Fresh Banana', 'Fresh Orange' , 'Fresh Potato', 'Fresh Tomato', 'Fresh Carrot', 'Fresh Meat',
           'Stale Apple' , 'Stale Banana','Stale Orange', 'Stale Potato', 'Stale Tomato', 'Stale Carrot', 'Stale Meat']

threshold = 0.5

def predict(filename , model):
    img = load_img(filename , target_size = (224, 224))
    img = img_to_array(img)
    img = img.reshape(1 , 224 ,224 ,3)

    img = img.astype('float32')
    img = img/255.0
    result = model.predict(img)

    dict_result = {}
    for i in range(len(classes)):
        dict_result[result[0][i]] = classes[i]

    res = result[0]
    res.sort()
    res = res[::-1]
    prob = res[:3]

    prob_result = []
    class_result = []
    for i in range(3):
        prob_result.append((prob[i]*100).round(2))
        class_result.append(dict_result[prob[i]])

    # Check if the highest probability is below the threshold
    if prob[0] < threshold:
        return ["tidak terdeteksi"], [0.0]
    return class_result,prob_result

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from google.colab import files

uploaded = files.upload()
for fn in uploaded.keys():
    # predicting images
    img_path = fn

image = mpimg.imread(img_path)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-936c0b7f-934a-4d81-ae68-38d2efb5e23d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-936c0b7f-934a-4d81-ae68-38d2efb5e23d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# class_result, prob_result = predict_with_exception_handler(img_path, model)
class_result, prob_result = predict(img_path, model)

predictions = {
    "class": class_result[0],
    "prob": prob_result[0]
}

print(f'Classified as: {predictions["class"]}')
print(f'Probability: {predictions["prob"]} %')
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Classified as: tidak terdeteksi
# Probability: 0.0 %

# %%
# # from tensorflow import lite
# # from tensorflow import keras
# import tensorflow as tf

# # saved_model = 'gdrive/My Drive/Mobile Net/capstone.h5'
# saved_model = tf.keras.models.load_model('gdrive/My Drive/Mobile Net/capstone.h5')

# converter = tf.lite.TFLiteConverter.from_keras_model(saved_model)
# tflite_model = converter.convert()

# # tflite_model_path = 'gdrive/My Drive/Mobile Net/capstone.tflite'

# open('capstone.tflite', 'wb').write(tflite_model)

# # print(f"saved at : {tflite_model_path}")
